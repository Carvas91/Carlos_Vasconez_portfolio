# %%
import pandas as pd

# %%
df = pd.read_csv('/content/lista_archivos.csv')

# %%
df.head(3)
# Out:
#                                    Nombre de Archivo    Fecha de Creación  \
# 0                                #ilovemypitbull.png  2018-01-07 12:55:38
# 1                                   #picoftheday.png  2018-01-01 21:15:47
# 2  00_MUIA_Razonamiento_y_Planificacion_Refuerzo_...  2024-02-25 14:58:35
#
#   Fecha de Último Acceso  Tamaño del Archivo (bytes)  Tipo de Archivo
# 0    2023-09-18 21:35:18                     1507822        image/png
# 1    2023-09-18 21:36:41                     1190894        image/png
# 2    2024-02-25 15:55:03                     1568577  application/pdf

# %%
df['Tipo de Archivo'].value_counts()
# Out:
# application/pdf                                                              1307
# application/vnd.openxmlformats-officedocument.wordprocessingml.document       609
# application/vnd.openxmlformats-officedocument.presentationml.presentation     193
# application/vnd.openxmlformats-officedocument.spreadsheetml.sheet             153
# image/jpeg                                                                    112
# application/vnd.ms-excel                                                       95
# image/png                                                                      94
# application/x-zip-compressed                                                   92
# Desconocido                                                                    84
# video/mp4                                                                      66
# application/x-msdownload                                                       34
# ...

# %%
# Filter the DataFrame to include only image files based on their MIME type.
df_img_sorted = df[df['Tipo de Archivo'].str.startswith('image/')].sort_values('Fecha de Último Acceso', ascending=True)

# %%
#select the oldest one I think I won't need in the future
df_img_delete = df_img_sorted.head(96)

# %%
df_img_delete
# Out:
#                                      Nombre de Archivo    Fecha de Creación  \
# 1615                               ken-reid-290762.jpg  2018-01-11 21:07:25
# 1557                                jf-brou-358069.jpg  2018-01-07 10:37:26
# 1452                                i just want to.png  2018-01-07 14:49:45
# 1449                            i just want to (1).png  2018-01-07 14:50:07
# 1790                              mike-burke-63930.jpg  2018-01-07 12:53:55
# ...                                                ...                  ...
# 1173                                    ertificate.png  2017-12-10 17:05:35
# 2825                            welcomelittle one!.png  2017-12-10 17:54:51
# 1698                          lopezbrownrealty.com.png  2017-11-05 15:02:02
# 2105                                         pug 2.png  2017-11-13 21:59:19
# 2764  Visit K9Glam.com for more great products (2).png  2017-11-21 20:32:52
#
# ...

# %%
# Save the names of the image files to be deleted to a CSV file, excluding the index.
df_img_delete['Nombre de Archivo'].to_csv('/content/lista_para_eliminar.csv', index=False)
